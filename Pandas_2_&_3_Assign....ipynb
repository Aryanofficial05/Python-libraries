# %% [markdown]
# # Q1. Display First Rows
#
# ## Problem Statement
# Create the following DataFrame:
#
# | Name | Age |
# |------|-----|
# | Aman | 21 |
# | Rahul | 22 |
# | Neha | 20 |
# | Priya | 23 |
# | Ravi | 24 |
#
# Display the first 3 rows using `head()`.
#
# ## Sample Output
# ```python
# First 3 rows of DataFrame
# ```

# %%
import pandas as pd
a = {
        'Name':['Aman','Rahul','Neha','priya','Ravi'],
        'Age':[21,22,20,23,24],
    }
b=pd.DataFrame(a)


#print(b)
print(b.head(3))
# Out:
#     Name  Age
# 0   Aman   21
# 1  Rahul   22
# 2   Neha   20

# %% [markdown]
# # Q2. Display Last Rows
#
# ## Problem Statement
# Create a DataFrame containing 6 student records.
#
# Display the last 2 rows using `tail()`.
#
# ## Sample Output
# ```python
# Last 2 rows of DataFrame
# ```

# %%
print(b.tail(2))
# Out:
#     Name  Age
# 3  priya   23
# 4   Ravi   24

# %% [markdown]
# # Q3. Check DataFrame Information
#
# ## Problem Statement
# Create a DataFrame containing:
#
# ```python
# Name = ["Aman","Rahul","Neha"]
# Marks = [80,75,90]
# ```
#
# Display DataFrame information using `info()`.
#
# ## Sample Output
# ```python
# <class 'pandas.core.frame.DataFrame'>
# ...
# ```

# %%
a = pd.DataFrame({
    'Name':['Aman','Rahul','Neha'],
    'Marks':[80,75,90]
})
print(a.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Marks   3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 180.0+ bytes
# None

# %% [markdown]
# # Q4. Shape and Data Types
#
# ## Problem Statement
# Create a DataFrame with:
#
# ```python
# Name
# Age
# City
# ```
#
# Print:
# - Shape
# - Data Types
#
# ## Sample Output
# ```python
# (3,3)
# object
# int64
# ```

# %%
import pandas as pd
a = {
        'Name':['Aman','Rahul','Neha','priya','Ravi'],
        'Age':[21,22,20,23,24],
        'city':['berlin','tokeyo','mexico','reo','landon']
    }
b=pd.DataFrame(a)
print(b.shape)
print(b.dtypes)
# Out:
# (5, 3)
# Name    object
# Age      int64
# city    object
# dtype: object

# %% [markdown]
# # Q5. Select Data using loc
#
# ## Problem Statement
# Create a DataFrame with Name, Age and City.
#
# Using `loc`, display the Name and City of the first row.
#
# ## Sample Output
# ```python
# Name    Aman
# City    Bhopal
# ```

# %%
a = {
        'Name':['Aman','Rahul','Neha','priya','Ravi'],
        'Age':[21,22,20,23,24],
        'city':['berlin','tokeyo','mexico','reo','landon']
    }
b=pd.DataFrame(a)
print(b.loc[3])
# Out:
# Name    priya
# Age        23
# city      reo
# Name: 3, dtype: object

# %% [markdown]
# # Q6. Select Data using iloc
#
# ## Problem Statement
# Create a DataFrame with at least 4 rows.
#
# Using `iloc`, print:
# - Second row
# - First two columns
#
# ## Sample Output
# ```python
# Selected row values
# ```

# %%
print(b.iloc[0:2,0:3])
# Out:
#     Name  Age    city
# 0   Aman   21  berlin
# 1  Rahul   22  tokeyo

# %% [markdown]
# # Q7. Rename a Column
#
# ## Problem Statement
# Create a DataFrame:
#
# ```python
# Name
# Marks
# ```
#
# Rename column `Marks` to `Score`.
#
# ## Sample Output
# ```python
# Name  Score
# ```

# %%
a = {
        'Name':['Aman','Rahul','Neha','priya','Ravi'],
        'Age':[21,22,20,23,24],
    }
b=pd.DataFrame(a)
print(b.rename(columns = {'Age':'Score'},inplace = True))
print(b)
# Out:
# None
#     Name  Score
# 0   Aman     21
# 1  Rahul     22
# 2   Neha     20
# 3  priya     23
# 4   Ravi     24

# %% [markdown]
# # Q8. Handle Missing Values
#
# ## Problem Statement
# Create a DataFrame:
#
# ```python
# Name = ["Aman", None, "Neha"]
# Marks = [80, 75, None]
# ```
#
# Fill missing values using `fillna()`.
#
# ## Sample Output
# ```python
# Missing values replaced
# ```

# %%
import pandas as pd
a = pd.DataFrame ({
"Name" : ["Aman",None,"neha"],
"Marks" : [80,75,None],
})
a['Name'] = a['Name'].fillna("unknown")
a['Marks'] = a['Marks'].fillna(a['Marks'].mean())

print(a)
# Out:
#       Name  Marks
# 0     Aman   80.0
# 1  unknown   75.0
# 2     neha   77.5

# %% [markdown]
# # Q9. Replace Values
#
# ## Problem Statement
# Create a DataFrame:
#
# ```python
# City = ["BPL", "IND", "BPL"]
# ```
#
# Replace:
# - BPL → Bhopal
# - IND → Indore
#
# ## Sample Output
# ```python
# Bhopal
# Indore
# Bhopal
# ```

# %%
a = pd.DataFrame({
    "city":['BPL','IND','BPL']
})
a['city'].replace('BPL','Bhopal',inplace = True)
a['city'].replace('IND','Indore',inplace = True)
print(a)
# Out:
#      city
# 0  Bhopal
# 1  Indore
# 2  Bhopal
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_25928\544697499.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   a['city'].replace('BPL','Bhopal',inplace = True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_25928\544697499.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   a['city'].replace('IND','Indore',inplace = True)

# %% [markdown]
# # Q10. Remove Duplicate Records
#
# ## Problem Statement
# Create a DataFrame:
#
# ```python
# Name = ["Aman","Rahul","Aman","Neha"]
# ```
#
# Check duplicate rows using `duplicated()` and remove them using `drop_duplicates()`.
#
# ## Sample Output
# ```python
# Aman
# Rahul
# Neha
# ```

# %%
a = pd.DataFrame({
    "Name": ['Aman','Rahul','Aman','Aman']
})
a.drop_duplicates(inplace = True)
print(a)
# Out:
#     Name
# 0   Aman
# 1  Rahul
